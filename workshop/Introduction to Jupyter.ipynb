# %% [markdown]
# Jupyter is an interactive development environment that allows you to write code step-by-step, saving and re-running chunks of code as necessary. Notebooks are best for exploration and explanation, but if you want to re-use your work somewhere else you can click `File > Download As > Python (.py)` and run the whole notebook in order as one script.
#
# Jupyter used to be called "IPython Notebook" and a lot of documentation refers to it that way still. But now Jupyter supports other languages too (like Lua/Torch with iTorch) and it's more general purpose. A complete introduction to Jupyter is available [here](http://jupyter-notebook.readthedocs.io/en/latest/notebook.html).
#
# In Jupyter code is divided into cells. Evaluate a cell by selecting it and then clicking `Cell > Run` or by typing `Shift + Enter`. Try it on the next cell.

# %%
print 'Hello world!!'
# Out:
# Hello world!!

# %% [markdown]
# Besides printing out things you tell it to print, Jupyter will also print out the value of the last line in a cell.

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# All data is stored "behind the scenes" and can be passed between cells. First evaluate the next cell:

# %%
word = 'little'

# %% [markdown]
# Then evaluate the next cell.

# %%
phrase = word + ' by ' + word
print phrase
# Out:
# little by little

# %% [markdown]
# If an operation is running for too long, we can cancel it by pressing the "stop" button above. Try running the following cell then pressing the "stop" button above.

# %%
for i in range(30):
    sleep(1)

# %% [markdown]
# Normally the cell will print some error information about the line it stopped on, similar to pressing `Ctrl-C` in a shell.
#
# If your code is really stuck, sometimes you need to restart everything. To do that, press the `Restart Kernel` button. This will clear any intermediate results you have, including any saved variables and defined functions.
#
# One more really important thing to know about Jupyter is that it interfaces nicely with matplotlib, a plotting library. We can import matplotlib and use a special line beginning with `%` (called a "[magic](http://nbviewer.ipython.org/github/ipython/ipython/blob/1.x/examples/notebooks/Cell%20Magics.ipynb)"). Normally matplotlib renders in a pop-up window, but using the magic we can make sure it renders in the notebook.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from math import sin
plt.plot([sin(x/10.0) for x in range(100)])

# %% [markdown]
# Normally we would write `plt.show()` to show the plot, but `plt.plot()` returns the plot as a result, and Jupyter renders the last line automatically.
#
# Finally, it's also possible to render higher output for retina displays with matplotlib.

# %%
# %config InlineBackend.figure_format = 'retina'
plt.plot([sin(x/10.0) for x in range(100)])
